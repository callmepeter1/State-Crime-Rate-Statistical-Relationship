# %%
# Run this cell first, each time you open this file. 
import urllib.request
exec(urllib.request.urlopen("https://gannon.blackboard.com/bbcswebdav/users/nogaj001/math213/math213.py").read())
# Out:
# All course code is now loaded!

# %%
labels = "State", "Population", "Crime_per_1000", "Avg_F", "Inches"
values = ("ALABAMA", "ALASKA", "ARIZONA", "ARKANSAS", "CALIFORNIA", "COLORADO", "CONNECTICUT", "DELAWARE", "FLORIDA", "GEORGIA", "HAWAII", "IDAHO", "ILLINOIS", "INDIANA", "IOWA", "KANSAS", "KENTUCKY", "LOUISIANA", "MAINE", "MARYLAND", "MASSACHUSETTS", "MICHIGAN", "MINNESOTA", "MISSISSIPPI", "MISSOURI", "MONTANA", "NEBRASKA", "NEVADA", "NEW HAMPSHIRE", "NEW JERSEY", "NEW MEXICO", "NEW YORK", "NORTH CAROLINA", "NORTH DAKOTA", "OHIO", "OKLAHOMA", "OREGON", "PENNSYLVANIA", "RHODE ISLAND", "SOUTH CAROLINA", "SOUTH DAKOTA", "TENNESSEE", "TEXAS", "UTAH", "VERMONT", "VIRGINIA", "WASHINGTON", "WEST VIRGINIA", "WISCONSIN", "WYOMING"), (4447100, 626932, 5130632, 2673400, 33871648, 4301261, 3405565, 783600, 15982378, 8186453, 1211537, 1293953, 12419293, 6080485, 2926324, 2688418, 4041769, 4468976, 1274923, 5296486, 6349097, 9938444, 4919479, 2844658, 5595211, 902195, 1711263, 1998257, 1235786, 8414350, 1819046, 18976457, 8049313, 642200, 11353140, 3450654, 3421399, 12281054, 1048319, 4012012, 754844, 5689283, 20851820, 2233169, 608827, 7078515, 5894121, 1808344, 5363675, 493782), (45.45, 42.49, 58.29, 41.15, 37.39, 39.82, 32.32, 44.78, 56.94, 47.51, 51.98, 31.86, 42.86, 37.51, 32.33, 44.08, 29.59, 54.22, 26.19, 48.16, 30.26, 41.09, 34.88, 40.04, 45.27, 35.33, 40.95, 42.68, 24.33, 31.60, 55.18, 30.99, 49.19, 22.88, 40.41, 45.58, 48.45, 29.95, 34.76, 52.21, 23.19, 48.90, 49.55, 44.76, 29.86, 30.28, 51.05, 26.02, 32.09, 32.98), (62.8, 26.6, 60.3, 60.4, 59.4, 45.1, 49, 55.3, 70.7, 63.5, 70, 44.4, 51.8, 51.7, 47.8, 54.3, 55.6, 66.4, 41, 54.2, 47.9, 44.4, 41.2, 63.4, 54.4, 42.7, 48.8, 49.9, 43.8, 52.7, 53.4, 45.4, 59, 40.4, 50.7, 59.6, 48.4, 48.8, 50.1, 62.4, 45.2, 57.6, 64.8, 48.6, 42.9, 55.1, 48.3, 51.8, 43.1, 42), (58.3, 22.5, 13.6, 50.6, 22.2, 15.9, 50.3, 45.7, 54.5, 50.7, 63.7, 18.9, 39.2, 41.7, 34, 28.9, 48.9, 60.1, 42.2, 44.5, 47.7, 32.8, 27.3, 59, 42.2, 15.3, 23.6, 9.5, 43.4, 47.1, 14.6, 41.8, 50.3, 17.8, 39.1, 36.5, 27.4, 42.9, 47.9, 49.8, 20.1, 54.2, 28.9, 12.2, 42.7, 44.3, 38.4, 45.2, 32.6, 12.9)
load(manually)
# Out:
#              State  Population  Crime_per_1000   Avg_F  Inches
# 0          ALABAMA     4447100         45.4500 62.8000 58.3000
# 1           ALASKA      626932         42.4900 26.6000 22.5000
# 2          ARIZONA     5130632         58.2900 60.3000 13.6000
# 3         ARKANSAS     2673400         41.1500 60.4000 50.6000
# 4       CALIFORNIA    33871648         37.3900 59.4000 22.2000
# 5         COLORADO     4301261         39.8200 45.1000 15.9000
# 6      CONNECTICUT     3405565         32.3200 49.0000 50.3000
# 7         DELAWARE      783600         44.7800 55.3000 45.7000
# 8          FLORIDA    15982378         56.9400 70.7000 54.5000
# 9          GEORGIA     8186453         47.5100 63.5000 50.7000
# 10          HAWAII     1211537         51.9800 70.0000 63.7000
# 11           IDAHO     1293953         31.8600 44.4000 18.9000
# 12        ILLINOIS    12419293         42.8600 51.8000 39.2000
# 13         INDIANA     6080485         37.5100 51.7000 41.7000
# ...

# %%
multiple_regression(("Population", "Crime_per_1000", "Avg_F"), "Inches", show = True)
# Out:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# Regression equation:
# Inches = -9.1410 + -0.0000(Population) + -0.5729(Crime_per_1000) + 1.3629(Avg_F)
#                   Coef  SE Coef       t      p
# Constant       -9.1410  10.3762 -0.8810 0.3828
# Population      0.0000   0.0000 -1.1030 0.2756
# Crime_per_1000 -0.5729   0.2266 -2.5278 0.0149
# Avg_F           1.3629   0.2553  5.3389 0.0000
# standard error of the residuals (estimate) (SER or s): 11.7811
# r-squared: 0.3917
# adjusted r-squared: 0.3521
# n: 50
#
# Analysis of Variance:
# sum of squares due to regression (SSR):  4111.7661
# sum of squares error (SSE):  6384.4997
# sum of squares total (SST):  10496.2658
# mean square regression (MSR): 1370.5887
# mean square error (MSE): 138.7935
# F_data: 9.8750
# p-value: 0.0000
# 9.875022948533319

# %%
multiple_regression(("Crime_per_1000", "Avg_F"), "Inches", show = True)
# Out:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# Regression equation:
# Inches = -7.3869 + -0.5548(Crime_per_1000) + 1.2811(Avg_F)
#                   Coef  SE Coef       t      p
# Constant       -7.3869  10.2773 -0.7188 0.4758
# Crime_per_1000 -0.5548   0.2266 -2.4489 0.0180
# Avg_F           1.2811   0.2448  5.2327 0.0000
# standard error of the residuals (estimate) (SER or s): 11.8082
# r-squared: 0.3756
# adjusted r-squared: 0.3491
# n: 50
#
# Analysis of Variance:
# sum of squares due to regression (SSR):  3942.8967
# sum of squares error (SSE):  6553.3691
# sum of squares total (SST):  10496.2658
# mean square regression (MSR): 1971.4483
# mean square error (MSE): 139.4334
# F_data: 14.1390
# p-value: 0.0000
# 14.13899790052325

# %%
perform(linear_regression, "Crime_per_1000", "Inches", show=True)
# Out:
# Scatterplot of data and regression line:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# regression equation coefficients:
#     b0: 30.3192
#     b1: 0.1699
# p-value (b1 != 0): 0.4504
# r-squared: 0.0119
# correlation coefficient (r): 0.1092
# standard error of the residuals (estimate) (SER or s): 14.6992
# standard error of slope (se): 0.2232
# sum of squares total (SST):  10496.2658
# sum of squares error (SSE):  10371.1480
# sum of squares due to regression (SSR):  125.1178
#
# predicted values: [38.0389, 37.5362, 40.2198, 37.3086, 36.6699, 37.0827, 35.8088, 37.9251, 39.9905, 38.3888, 39.148, 35.7306, 37.599, 36.6903, 35.8105, 37.8062, 35.3451, 39.5285, 34.7676, 38.4992, 35.4589, 37.2984, 36.2436, 37.12, 38.0083, 36.32, 37.2746, 37.5684, 34.4517, 35.6865, 39.6916, 35.5829, 38.6742, 34.2054, 37.1829, 38.061, 38.5485, 35.4062, 36.2232, 39.1871, 34.258, 38.6249, 38.7353, 37.9217, 35.3909, 35.4623, 38.9901, 34.7387, 35.7697, 35.9209]
# ...

# %%
slope, standard_error = linear_regression("Crime_per_1000", "Inches", show=True)
p_value(t, null_value = 0, data_value = slope, scale = standard_error, degrees_of_freedom = stat(size) - 2, tails = "two", alpha = 0.05, graph = True)
# Out:
# Scatterplot of data and regression line:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# regression equation coefficients:
#     b0: 30.3192
#     b1: 0.1699
# p-value (b1 != 0): 0.4504
# r-squared: 0.0119
# correlation coefficient (r): 0.1092
# standard error of the residuals (estimate) (SER or s): 14.6992
# standard error of slope (se): 0.2232
# sum of squares total (SST):  10496.2658
# sum of squares error (SSE):  10371.1480
# sum of squares due to regression (SSR):  125.1178
#
# predicted values: [38.0389, 37.5362, 40.2198, 37.3086, 36.6699, 37.0827, 35.8088, 37.9251, 39.9905, 38.3888, 39.148, 35.7306, 37.599, 36.6903, 35.8105, 37.8062, 35.3451, 39.5285, 34.7676, 38.4992, 35.4589, 37.2984, 36.2436, 37.12, 38.0083, 36.32, 37.2746, 37.5684, 34.4517, 35.6865, 39.6916, 35.5829, 38.6742, 34.2054, 37.1829, 38.061, 38.5485, 35.4062, 36.2232, 39.1871, 34.258, 38.6249, 38.7353, 37.9217, 35.3909, 35.4623, 38.9901, 34.7387, 35.7697, 35.9209]
# ...

# %%
# The linear line is almost horizontal, which means there is almost no linear relationship between precipitation and crime rate.
# Do not reject the null hypothesis, p_value = 0.45 > 0.05
# We can conclude that precipitation and crime rate do not have significant linear relationship.

# %%
perform(linear_regression, "Avg_F", "Inches", show=True)
# Out:
# Scatterplot of data and regression line:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# regression equation coefficients:
#     b0: -10.4283
#     b1: 0.9146
# p-value (b1 != 0): 0.0000
# r-squared: 0.2960
# correlation coefficient (r): 0.5440
# standard error of the residuals (estimate) (SER or s): 12.4076
# standard error of slope (se): 0.2036
# sum of squares total (SST):  10496.2658
# sum of squares error (SSE):  7389.5712
# sum of squares due to regression (SSR):  3106.6946
#
# predicted values: [47.0088, 13.9001, 44.7223, 44.8137, 43.8991, 30.8203, 34.3872, 40.1492, 54.2341, 47.649, 53.5939, 30.1801, 36.9481, 36.8567, 33.2897, 39.2346, 40.4236, 50.3013, 27.0704, 39.1432, 33.3812, 30.1801, 27.2533, 47.5575, 39.3261, 28.6252, 34.2043, 35.2104, 29.6313, 37.7713, 38.4115, 31.0947, 43.5333, 26.5216, 35.9421, 44.082, 33.8385, 34.2043, 35.3933, 46.6429, 30.9117, 42.2528, 48.838, 34.0214, 28.8082, 39.9663, 33.747, 36.9481, 28.9911, 27.985]
# ...

# %%
# Based on the graph, it looks like there is a positive relationship between temperature and precipitation.

# %%
multiple_regression(("Population", "Crime_per_1000"), "Avg_F", show = True)
# Out:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# Regression equation:
# Avg_F = 28.7572 + 0.0000(Population) + 0.5365(Crime_per_1000)
#                   Coef  SE Coef      t      p
# Constant       28.7572   4.1900 6.8633 0.0000
# Population      0.0000   0.0000 2.0821 0.0427
# Crime_per_1000  0.5365   0.1032 5.2003 0.0000
# standard error of the residuals (estimate) (SER or s): 6.7315
# r-squared: 0.4266
# adjusted r-squared: 0.4022
# n: 50
#
# Analysis of Variance:
# sum of squares due to regression (SSR):  1584.1859
# sum of squares error (SSE):  2129.7359
# sum of squares total (SST):  3713.9218
# mean square regression (MSR): 792.0929
# mean square error (MSE): 45.3135
# F_data: 17.4803
# p-value: 0.0000
# 17.48027383544389

# %%
# There seems to be some sort of positive correlations.

# %%
slope, standard_error = linear_regression("Crime_per_1000", "Avg_F", show=True)
p_value(t, null_value = 0, data_value = slope, scale = standard_error, degrees_of_freedom = stat(size) - 2, tails = "two", alpha = 0.05, graph = True)
# Out:
# Scatterplot of data and regression line:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# regression equation coefficients:
#     b0: 29.4326
#     b1: 0.5657
# p-value (b1 != 0): 0.0000
# r-squared: 0.3737
# correlation coefficient (r): 0.6113
# standard error of the residuals (estimate) (SER or s): 6.9615
# standard error of slope (se): 0.1057
# sum of squares total (SST):  3713.9218
# sum of squares error (SSE):  2326.1829
# sum of squares due to regression (SSR):  1387.7389
#
# predicted values: [55.1422, 53.4678, 62.4054, 52.7098, 50.5829, 51.9575, 47.715, 54.7632, 61.6417, 56.3075, 58.836, 47.4548, 53.6771, 50.6508, 47.7206, 54.3672, 46.1707, 60.1031, 44.2474, 56.6752, 46.5497, 52.6759, 49.1631, 52.0819, 55.0404, 49.4176, 52.5967, 53.5753, 43.1953, 47.3077, 60.6462, 46.9626, 57.2578, 42.3751, 52.2912, 55.2157, 56.8392, 46.3744, 49.0952, 58.9661, 42.5504, 57.0938, 57.4615, 54.7519, 46.3234, 46.561, 58.31, 44.1513, 47.5849, 48.0883]
# ...

# %%
# Reject the null hypothesis
# There is the positive correlation between crime rate  and temperature.

# %%
multiple_regression(("Avg_F", "Crime_per_1000"), "Population", show = True)
# Out:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# Regression equation:
# Population = -5540431.4422 + 258477.4101(Avg_F) + -57005.7059(Crime_per_1000)
#                         Coef      SE Coef       t      p
# Constant       -5540431.4422 5211107.7524 -1.0632 0.2930
# Avg_F            258477.4101  124140.6121  2.0821 0.0427
# Crime_per_1000   -57005.7059  114878.3435 -0.4962 0.6220
# standard error of the residuals (estimate) (SER or s): 5987366.0872
# r-squared: 0.1013
# adjusted r-squared: 0.0631
# n: 50
#
# Analysis of Variance:
# sum of squares due to regression (SSR):  189926365991486.9062
# sum of squares error (SSE):  1684881975128798.2500
# sum of squares total (SST):  1874808341120285.0000
# mean square regression (MSR): 94963182995743.4531
# mean square error (MSE): 35848552662314.8594
# F_data: 2.6490
# p-value: 0.0813
# 2.6490102373246374

# %%
slope, standard_error = linear_regression("Crime_per_1000", "Population", show=True)
p_value(t, null_value = 0, data_value = slope, scale = standard_error, degrees_of_freedom = stat(size) - 2, tails = "two", alpha = 0.05, graph = True)
# Out:
# Scatterplot of data and regression line:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# regression equation coefficients:
#     b0: 38.6335
#     b1: 0.0000
# p-value (b1 != 0): 0.3475
# r-squared: 0.0184
# correlation coefficient (r): 0.1357
# standard error of the residuals (estimate) (SER or s): 9.4175
# standard error of slope (se): 0.0000
# sum of squares total (SST):  4336.9478
# sum of squares error (SSE):  4257.1103
# sum of squares due to regression (SSR):  79.8375
#
# predicted values: [39.5512, 38.7629, 39.6922, 39.1852, 45.6232, 39.5211, 39.3362, 38.7952, 41.9316, 40.3228, 38.8835, 38.9005, 41.1963, 39.8882, 39.2374, 39.1883, 39.4675, 39.5557, 38.8966, 39.7265, 39.9437, 40.6844, 39.6487, 39.2205, 39.7881, 38.8197, 38.9866, 39.0458, 38.8885, 40.3699, 39.0089, 42.5495, 40.2945, 38.766, 40.9763, 39.3456, 39.3395, 41.1678, 38.8498, 39.4614, 38.7892, 39.8075, 42.9365, 39.0943, 38.7591, 40.0942, 39.8498, 39.0066, 39.7403, 38.7354]
# ...

# %%
# Do not reject the null hypothesis
# The is no correlation between population and crime rate.

# %%
slope, standard_error = linear_regression("Avg_F", "Population", show=True)
p_value(t, null_value = 0, data_value = slope, scale = standard_error, degrees_of_freedom = stat(size) - 2, tails = "two", alpha = 0.05, graph = True)
# Out:
# Scatterplot of data and regression line:
# Scatterplot of residuals vs. predicted values:
# Normal probability plot of residuals:
# regression equation coefficients:
#     b0: -5852920.6222
#     b1: 220821.6388
# p-value (b1 != 0): 0.0280
# r-squared: 0.0966
# correlation coefficient (r): 0.3108
# standard error of the residuals (estimate) (SER or s): 5940169.3259
# standard error of slope (se): 97472.5768
# sum of squares total (SST):  1874808341120285.0000
# sum of squares error (SSE):  1693709357788238.7500
# sum of squares due to regression (SSR):  181098983332046.7500
#
# ...

# %%
# Reject the null hypothesis
# There is a positive correlation between poppulation and average temperature
